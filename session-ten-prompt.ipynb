# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
random = np.random.binomial(n=10, p=0.5, size=1000)

# %%
plt.hist(random, bins=100)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.savefig("randomtwo.pdf")
plt.show()
